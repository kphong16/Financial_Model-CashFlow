# %%
import pandas as pd

# %%
a = pd.DataFrame({'a':[1,2,3], 'b':[5,3,7]}, index=[1,2,3])
b = pd.DataFrame({'c':[7,3,5], 'd':[9,5,3]}, index=[0,1,2])

# %%
pd.concat([a, b], axis=1)
# Out:
#      a    b    c    d
# 0  NaN  NaN  7.0  9.0
# 1  1.0  5.0  3.0  5.0
# 2  2.0  3.0  5.0  3.0
# 3  3.0  7.0  NaN  NaN

# %%
a.append??

# %%
class abc:
    def __init__(self):
        pass

# %%
a = abc()

# %%
a.object
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-1417313c104f> in <module>
# ----> 1 a.object
#
# AttributeError: 'abc' object has no attribute 'object'

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import pandas as pd',
#   "a = pd.DataFrame({'a':[1,2,3], 'b':[5,3,7]})\nb = pd.DataFrame({'c':[7,3,5], 'd':[9,5,3]})",
#   'a.append(b)',
#   "get_ipython().run_line_magic('pinfo2', 'a.append')",
#   "a = pd.DataFrame({'a':[1,2,3], 'b':[5,3,7]}, index=[0,1,2])\nb = pd.DataFrame({'c':[7,3,5], 'd':[9,5,3]}, index=[0,1,2])",
#   'a.append(b)',
#   "a = pd.DataFrame({'a':[1,2,3], 'b':[5,3,7]}, index=[1,2,3])\nb = pd.DataFrame({'c':[7,3,5], 'd':[9,5,3]}, index=[0,1,2])",
#   'a.append(b)',
#   'pd.concat([a, b])',
#   'pd.concat([a, b], join=inner)',
#   "pd.concat([a, b], join='inner')",
#   "pd.concat([a, b], join='inner', axis=1)",
#   "pd.concat([a, b], join='outer', axis=1)",
# ...
